# %%
import requests  ## Loads the Url mentione, it hits the Url and gets the status code whether website is working or not, or url is correct or not
from bs4 import BeautifulSoup  ## Library used for Web Scraping

# %%
url = "https://www.amazon.in/Xtore-Ultra-Comfortable-Pollution-Replaceable-Breathing/product-reviews/B07M7ZRFR5/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

# %%
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
page.content  ## Gives whole source code of the Url we mentioned
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n\n<!-- sp:end-feature:csm:head-open-part2 -->\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://m.media-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41tGz3DNCrL.css,31ufSReDtSL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.
# ...

# %%
soup = BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <!-- sp:end-feature:csm:head-open-part2 -->
#   <!-- sp:feature:aui-assets -->
# ...

# %%
# Searching 5 data for the Review : 1. Customer name 2. Star Rating 3. Review Title  4. Date  5. Actual Review
## Scraping Customer name 

names = soup.find_all('span', class_='a-profile-name')[2:]

# %%
names
# Out:
# [<span class="a-profile-name">K S.</span>,
#  <span class="a-profile-name">Madhuri shelar</span>,
#  <span class="a-profile-name">Madhuri shelar</span>,
#  <span class="a-profile-name">amoljatale</span>,
#  <span class="a-profile-name">Krishnendu Pal</span>,
#  <span class="a-profile-name">Saloni</span>,
#  <span class="a-profile-name">Narendra K Gandhi</span>,
#  <span class="a-profile-name">Narendra K Gandhi</span>,
#  <span class="a-profile-name">Paritosh Joshi</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">Ramesh Rengasamy</span>,
#  <span class="a-profile-name">Uday M</span>]

# %%
len(names)
# Out:
# 12

# %%
## Removing the tag part

cust_name = []
for i in range(0,len(names)): cust_name.append(names[i].get_text())

# %%
print(cust_name)
# Out:
# ['K S.', 'Madhuri shelar', 'Madhuri shelar', 'amoljatale', 'Krishnendu Pal', 'Saloni', 'Narendra K Gandhi', 'Narendra K Gandhi', 'Paritosh Joshi', 'Amazon Customer', 'Ramesh Rengasamy', 'Uday M']

# %%
cust_name.pop(0)
# Out:
# 'K S.'

# %%
len(cust_name)
# Out:
# 11

# %%
cust_name.pop(0)
# Out:
# 'Madhuri shelar'

# %%
len(cust_name)
# Out:
# 10

# %%
print(cust_name)
# Out:
# ['Madhuri shelar', 'amoljatale', 'Krishnendu Pal', 'Saloni', 'Narendra K Gandhi', 'Narendra K Gandhi', 'Paritosh Joshi', 'Amazon Customer', 'Ramesh Rengasamy', 'Uday M']

# %%
## Now Fetching the Star Rating

stars = soup.find_all('span', class_='a-icon-alt')[3:]

# %%
print(stars)
# Out:
# [<span class="a-icon-alt">2.0 out of 5 stars</span>, <span class="a-icon-alt">3.0 out of 5 stars</span>, <span class="a-icon-alt">3.0 out of 5 stars</span>, <span class="a-icon-alt">2.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">3.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">3.0 out of 5 stars</span>]

# %%
len(stars)
# Out:
# 12

# %%
stars.pop(0)
# Out:
# <span class="a-icon-alt">2.0 out of 5 stars</span>

# %%
len(stars)
# Out:
# 11

# %%
stars.pop(0)
# Out:
# <span class="a-icon-alt">3.0 out of 5 stars</span>

# %%
len(stars)
# Out:
# 10

# %%
print(stars)
# Out:
# [<span class="a-icon-alt">3.0 out of 5 stars</span>, <span class="a-icon-alt">2.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">3.0 out of 5 stars</span>, <span class="a-icon-alt">4.0 out of 5 stars</span>, <span class="a-icon-alt">3.0 out of 5 stars</span>]

# %%
cust_rating = []
for i in range(0,len(stars)): cust_rating.append(stars[i].get_text())

# %%
print(cust_rating)
# Out:
# ['3.0 out of 5 stars', '2.0 out of 5 stars', '4.0 out of 5 stars', '4.0 out of 5 stars', '4.0 out of 5 stars', '4.0 out of 5 stars', '4.0 out of 5 stars', '3.0 out of 5 stars', '4.0 out of 5 stars', '3.0 out of 5 stars']

# %%
## Fetching title

title = soup.select('a.review-title span')

# %%
print(title)
# Out:
# [<span>Bad</span>, <span>Fooling with good pictures..Worst quality 🙄</span>, <span>Good to use for non medical personnel ...not N95 as many people expect</span>, <span>Excellent Quality Mask. Should give 4 filters for each mask.</span>, <span>Super comfy soft</span>, <span>Air valves wrongly fixed upside down</span>, <span>Decent mask</span>, <span>Mismatch in product photo</span>, <span>The PM2.5 filter can't be washed</span>, <span>Well designed and comfortable..</span>]

# %%
review_title = []
for i in range(0,len(title)): review_title.append(title[i].get_text())

# %%
print(review_title)
# Out:
# ['Bad', 'Fooling with good pictures..Worst quality 🙄', 'Good to use for non medical personnel ...not N95 as many people expect', 'Excellent Quality Mask. Should give 4 filters for each mask.', 'Super comfy soft', 'Air valves wrongly fixed upside down', 'Decent mask', 'Mismatch in product photo', "The PM2.5 filter can't be washed", 'Well designed and comfortable..']

# %%
## Fetching Date

dates = soup.select('span.review-date')[2:]

# %%
print(dates)
# Out:
# [<span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 30 October 2022</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 29 July 2020</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 17 July 2020</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 16 June 2020</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 10 July 2021</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 9 September 2020</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 18 August 2020</span>, <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 5 May 202
# ...

# %%
rev_date = []
for i in range(0,len(dates)): rev_date.append(dates[i].get_text())

# %%
print(rev_date)
# Out:
# ['Reviewed in India 🇮🇳 on 30 October 2022', 'Reviewed in India 🇮🇳 on 29 July 2020', 'Reviewed in India 🇮🇳 on 17 July 2020', 'Reviewed in India 🇮🇳 on 16 June 2020', 'Reviewed in India 🇮🇳 on 10 July 2021', 'Reviewed in India 🇮🇳 on 9 September 2020', 'Reviewed in India 🇮🇳 on 18 August 2020', 'Reviewed in India 🇮🇳 on 5 May 2021', 'Reviewed in India 🇮🇳 on 8 August 2020', 'Reviewed in India 🇮🇳 on 22 June 2020']

# %%
## Fetching the main review

details = soup.select('span.review-text-content span')

# %%
len(details)
# Out:
# 10

# %%
print(details)
# Out:
# [<span>Bad</span>, <span>Not as good as they are telling about it...it is comfortable to wear ,the fabric used is so good...but Color fade away after 1 month only...I bought 2 pieces...and after 2 months its filter came out and I can't help with that.. Terrific purchase...please don't waste your money here guys.. fooling us with good pictures nothing else...Better to buy From nearby store ... I'm posting it's picture after use of 2 months..hope it's helpful</span>, <span>When the COVID-19 outbreak began in India, given the demand for effective N95 masks, two government agencies other than BIS also began testing them: the South Indian Textile Research Agency (SITRA), Coimbatore, and a facility of the Defence Research and Development Organisation (DRDO) in Gwalior. But these two agencies offered only one-time testing, to help manufacturers refine their prototypes. And neither is a certifying agency.<br><br/>Further, even the one-time tests are limited. Both agencies test only three of 
# ...

# %%
rev_body = []
for i in range(0,len(details)): rev_body.append(details[i].get_text())

# %%
print(rev_body)
# Out:
# ['Bad', "Not as good as they are telling about it...it is comfortable to wear ,the fabric used is so good...but Color fade away after 1 month only...I bought 2 pieces...and after 2 months its filter came out and I can't help with that.. Terrific purchase...please don't waste your money here guys.. fooling us with good pictures nothing else...Better to buy From nearby store ... I'm posting it's picture after use of 2 months..hope it's helpful", 'When the COVID-19 outbreak began in India, given the demand for effective N95 masks, two government agencies other than BIS also began testing them: the South Indian Textile Research Agency (SITRA), Coimbatore, and a facility of the Defence Research and Development Organisation (DRDO) in Gwalior. But these two agencies offered only one-time testing, to help manufacturers refine their prototypes. And neither is a certifying agency.Further, even the one-time tests are limited. Both agencies test only three of the many parameters under IS:9473, n
# ...

# %%
## Saving the data in the Data Frame

import pandas as pd

# %%
df = pd.DataFrame()

# %%
df["Date of Review"] = rev_date
df["Customer Name"] = cust_name
df["Customer Rating"] = cust_rating
df["Review Title"] = review_title
df["Reviews"] = rev_body

# %%
df.to_csv("reviews.csv")

# %%
df
# Out:
#                              Date of Review      Customer Name  \
# 0   Reviewed in India 🇮🇳 on 30 October 2022     Madhuri shelar
# 1      Reviewed in India 🇮🇳 on 29 July 2020         amoljatale
# 2      Reviewed in India 🇮🇳 on 17 July 2020     Krishnendu Pal
# 3      Reviewed in India 🇮🇳 on 16 June 2020             Saloni
# 4      Reviewed in India 🇮🇳 on 10 July 2021  Narendra K Gandhi
# 5  Reviewed in India 🇮🇳 on 9 September 2020  Narendra K Gandhi
# 6    Reviewed in India 🇮🇳 on 18 August 2020     Paritosh Joshi
# 7        Reviewed in India 🇮🇳 on 5 May 2021    Amazon Customer
# 8     Reviewed in India 🇮🇳 on 8 August 2020   Ramesh Rengasamy
# 9      Reviewed in India 🇮🇳 on 22 June 2020             Uday M
#
#       Customer Rating                                       Review Title  \
# 0  3.0 out of 5 stars                                                Bad
# 1  2.0 out of 5 stars        Fooling with good pictures..Worst quality 🙄
# ...

# %%
#### SENTIMENT ANALYSIS OF THE REVIEWS 

import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Ashutosh\AppData\Roaming\nltk_data...
# True

# %%
from nltk.sentiment.vader import  SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores("This mask is just a waste of money. Don't Buy!") ## compound is below zero which shows the sentiment to be negative
# Out:
# {'neg': 0.279, 'neu': 0.721, 'pos': 0.0, 'compound': -0.4753}

# %%
sia.polarity_scores("Good mask. Nice quality but won't buy again.") ## Compound is more than 0 which shows sentiment to be positive
# Out:
# {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'compound': 0.431}

# %%
sia.polarity_scores("Amazing mask. Value for money.")  ## Highly positive
# Out:
# {'neg': 0.0, 'neu': 0.326, 'pos': 0.674, 'compound': 0.7351}

# %%
sia.polarity_scores("just oaky") ## compound shows 0 when an absolute 0 comes, it shows the sentiment to be neutral.
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
## Analysing the sentiment for the Scraped Data now.

polarity_scores = []
for i in range(0,len(rev_body)): 
   s = sia.polarity_scores(rev_body[i])
   polarity_scores.append(s)

# %%
print(polarity_scores)
# Out:
# [{'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.5423}, {'neg': 0.119, 'neu': 0.741, 'pos': 0.14, 'compound': 0.4141}, {'neg': 0.108, 'neu': 0.832, 'pos': 0.059, 'compound': -0.8074}, {'neg': 0.0, 'neu': 0.83, 'pos': 0.17, 'compound': 0.9017}, {'neg': 0.131, 'neu': 0.635, 'pos': 0.234, 'compound': 0.1531}, {'neg': 0.065, 'neu': 0.895, 'pos': 0.041, 'compound': -0.2846}, {'neg': 0.152, 'neu': 0.739, 'pos': 0.109, 'compound': -0.2244}, {'neg': 0.087, 'neu': 0.827, 'pos': 0.087, 'compound': 0.0}, {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}, {'neg': 0.103, 'neu': 0.777, 'pos': 0.119, 'compound': 0.2006}]

# %%
## Taking out the positive review 

score = []
for i in range(0,len(polarity_scores)):
  c = polarity_scores[i]['compound']
  if c > 0:
   score.append("Positive")
  elif c == 0:
   score.append("Neutral")
  else:
   score.append("Negative")

# %%
print(score)
# Out:
# ['Negative', 'Positive', 'Negative', 'Positive', 'Positive', 'Negative', 'Negative', 'Neutral', 'Neutral', 'Positive']

# %%
## Adding this score to the DataFrame

df["Score"] = score

# %%
df
# Out:
#                              Date of Review      Customer Name  \
# 0   Reviewed in India 🇮🇳 on 30 October 2022     Madhuri shelar
# 1      Reviewed in India 🇮🇳 on 29 July 2020         amoljatale
# 2      Reviewed in India 🇮🇳 on 17 July 2020     Krishnendu Pal
# 3      Reviewed in India 🇮🇳 on 16 June 2020             Saloni
# 4      Reviewed in India 🇮🇳 on 10 July 2021  Narendra K Gandhi
# 5  Reviewed in India 🇮🇳 on 9 September 2020  Narendra K Gandhi
# 6    Reviewed in India 🇮🇳 on 18 August 2020     Paritosh Joshi
# 7        Reviewed in India 🇮🇳 on 5 May 2021    Amazon Customer
# 8     Reviewed in India 🇮🇳 on 8 August 2020   Ramesh Rengasamy
# 9      Reviewed in India 🇮🇳 on 22 June 2020             Uday M
#
#       Customer Rating                                       Review Title  \
# 0  3.0 out of 5 stars                                                Bad
# 1  2.0 out of 5 stars        Fooling with good pictures..Worst quality 🙄
# ...

# %%
## Piechart of positive, negative and neutral reviews.

import matplotlib.pyplot as plt

# %%
import matplotlib.patches as mpatches

# %%
df
# Out:
#                              Date of Review      Customer Name  \
# 0   Reviewed in India 🇮🇳 on 30 October 2022     Madhuri shelar
# 1      Reviewed in India 🇮🇳 on 29 July 2020         amoljatale
# 2      Reviewed in India 🇮🇳 on 17 July 2020     Krishnendu Pal
# 3      Reviewed in India 🇮🇳 on 16 June 2020             Saloni
# 4      Reviewed in India 🇮🇳 on 10 July 2021  Narendra K Gandhi
# 5  Reviewed in India 🇮🇳 on 9 September 2020  Narendra K Gandhi
# 6    Reviewed in India 🇮🇳 on 18 August 2020     Paritosh Joshi
# 7        Reviewed in India 🇮🇳 on 5 May 2021    Amazon Customer
# 8     Reviewed in India 🇮🇳 on 8 August 2020   Ramesh Rengasamy
# 9      Reviewed in India 🇮🇳 on 22 June 2020             Uday M
#
#       Customer Rating                                       Review Title  \
# 0  3.0 out of 5 stars                                                Bad
# 1  2.0 out of 5 stars        Fooling with good pictures..Worst quality 🙄
# ...

# %%
pie = df['Score'].value_counts().plot(kind="pie", autopct='%1.1f%%', labels=['Positive', 'Negative' , 'Neutral'])   
pie.set_title("Xtore® N95 Ultra-Comfortable Anti Pollution Mask | Replaceable Filter | Breathing Valve - (2 Mask, 4 Filters)", fontsize=18)
Positive = mpatches.Patch(color='blue', label='Positive')
Neutral = mpatches.Patch(color='green', label='Neutral')
Negative = mpatches.Patch(color='orange', label='Negative')
plt.legend(handles=[Positive,Neutral,Negative], loc='center left', bbox_to_anchor=(1, 0.5))
